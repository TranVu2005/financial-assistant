# %%
# %pip install pyarrow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# d:\GitHub\financial-assistant\.venv\Scripts\python.exe: No module named pip

# %%
import pandas as pd

df = pd.read_parquet("D:\\GitHub\\financial-assistant\\data\\processed\\release_v1_f481a496651d\\issues.parquet")

print(df.shape)

print(df.columns)

print(df.info())

display(df.head())

display(df.sample(5))

display(df.describe(include="all"))

print(df.isnull().sum())

print(df.duplicated().sum())
# Out:
# (2315162, 6)
# Index(['code', 'doc_id', 'table_id', 'cell_id', 'field', 'raw_value'], dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 2315162 entries, 0 to 2315161
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   code       str
#  1   doc_id     str
#  2   table_id   str
#  3   cell_id    str
#  4   field      str
#  5   raw_value  str
# dtypes: str(6)
# memory usage: 626.1 MB
# None
#            code                                             doc_id  \
# 0  unit_unknown  doc_437c2d109807ec6904088cc1de1b5becc2ba0b7661...
# 1  unit_unknown  doc_437c2d109807ec6904088cc1de1b5becc2ba0b7661...
# 2  unit_unknown  doc_437c2d109807ec6904088cc1de1b5becc2ba0b7661...
# 3  unit_unknown  doc_437c2d109807ec6904088cc1de1b5becc2ba0b7661...
# 4  unit_unknown  doc_437c2d109807ec6904088cc1de1b5becc2ba0b7661...
#
#                                             table_id  \
# 0  tbl_03a43b4a63e18f35caa28b6e7de824e4c2c91ec733...
# ...
